# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from keras.layers import MaxPooling2D,Conv2D,Dense,BatchNormalization,Dropout,GlobalAveragePooling2D,Flatten,Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# %%
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/dataset/brain-tumor-class.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
#checking train labels and images randomly
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.1, zoom_range=0.1, horizontal_flip=True)

import matplotlib.pyplot as plt

train_set_check = train_datagen.flow_from_directory('/content/brain-tumor-class/Training',
                                             target_size=(256,256),
                                             batch_size=16,
                                             class_mode='sparse', shuffle=True)

class_names = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
plt.figure(figsize=(15, 15))

batch=next(train_set_check)  

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    img=batch[0][i]                            
    plt.imshow(img)
    lab = int(batch[1][i])
    plt.title(class_names[lab], fontsize=20)
    plt.axis("off")
# Out:
# Found 2870 images belonging to 4 classes.

# %%
X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join('/content/brain-tumor-class','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('/content/brain-tumor-class','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:03<00:00, 253.48it/s]
# 100%|██████████| 395/395 [00:01<00:00, 359.24it/s]
# 100%|██████████| 822/822 [00:02<00:00, 284.31it/s]
# 100%|██████████| 827/827 [00:03<00:00, 250.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 302.76it/s]
# 100%|██████████| 105/105 [00:00<00:00, 758.18it/s]
# 100%|██████████| 115/115 [00:00<00:00, 424.76it/s]
# 100%|██████████| 74/74 [00:00<00:00, 134.19it/s]

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.2,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential

model_cnn = Sequential()
model_cnn.add(Input(shape=(150,150,3)))
model_cnn.add(Conv2D(128,(3,3)))
model_cnn.add(MaxPooling2D((2,2)))
model_cnn.add(BatchNormalization())
model_cnn.add(Conv2D(64,(3,3)))
model_cnn.add(MaxPooling2D((2,2)))
model_cnn.add(BatchNormalization())
model_cnn.add(Conv2D(32,(3,3)))
model_cnn.add(MaxPooling2D((2,2)))
model_cnn.add(BatchNormalization())
model_cnn.add(Flatten())
model_cnn.add(Dense(128,activation='relu'))
model_cnn.add(Dropout(0.2))
model_cnn.add(Dense(64,activation='relu'))
model_cnn.add(Dense(4,activation='softmax'))

# %%
model_cnn.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model_cnn.fit(X_train,y_train,validation_split=0.2, epochs=20, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/25
# 74/74 [==============================] - ETA: 0s - loss: 1.1181 - accuracy: 0.5824
# Epoch 00001: val_accuracy improved from -inf to 0.62245, saving model to effnet.h5
# 74/74 [==============================] - 41s 130ms/step - loss: 1.1181 - accuracy: 0.5824 - val_loss: 1.2467 - val_accuracy: 0.6224 - lr: 0.0010
# Epoch 2/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.6412 - accuracy: 0.7521
# Epoch 00002: val_accuracy did not improve from 0.62245
# 74/74 [==============================] - 9s 116ms/step - loss: 0.6417 - accuracy: 0.7514 - val_loss: 1.4834 - val_accuracy: 0.5119 - lr: 0.0010
# Epoch 3/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.4459 - accuracy: 0.8326
# Epoch 00003: val_accuracy improved from 0.62245 to 0.71769, saving model to effnet.h5
# 74/74 [==============================] - 8s 111ms/step - loss: 0.4466 - accuracy: 0.8327 - val_loss: 0.8145 - val_accuracy: 0.7177 - lr: 0.0010
# Epoch 4/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.3514 - accuracy: 0.8656
# Epoch 00004: val_accuracy improved from 0.71769 to 0.76190, saving model to effnet.h5
# 74/74 [==============================] - 8s 110ms/step - loss: 0.3501 - accuracy: 0.8659 - val_loss: 0.7015 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 5/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.2502 - accuracy: 0.9178
# Epoch 00005: val_accuracy improved from 0.76190 to 0.82143, saving model to effnet.h5
# 74/74 [==============================] - 9s 118ms/step - loss: 0.2505 - accuracy: 0.9178 - val_loss: 0.5279 - val_accuracy: 0.8214 - lr: 0.0010
# Epoch 6/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9268
# Epoch 00006: val_accuracy did not improve from 0.82143
# 74/74 [==============================] - 8s 109ms/step - loss: 0.1945 - accuracy: 0.9268 - val_loss: 1.0478 - val_accuracy: 0.6650 - lr: 0.0010
# Epoch 7/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.1770 - accuracy: 0.9396
# Epoch 00007: val_accuracy improved from 0.82143 to 0.87415, saving model to effnet.h5
# 74/74 [==============================] - 8s 110ms/step - loss: 0.1772 - accuracy: 0.9395 - val_loss: 0.5256 - val_accuracy: 0.8741 - lr: 0.0010
# Epoch 8/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.1149 - accuracy: 0.9670
# Epoch 00008: val_accuracy did not improve from 0.87415
# 74/74 [==============================] - 9s 117ms/step - loss: 0.1143 - accuracy: 0.9672 - val_loss: 1.5278 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 9/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9739
# Epoch 00009: val_accuracy improved from 0.87415 to 0.89116, saving model to effnet.h5
# 74/74 [==============================] - 9s 118ms/step - loss: 0.0848 - accuracy: 0.9736 - val_loss: 0.4284 - val_accuracy: 0.8912 - lr: 0.0010
# Epoch 10/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9730
# Epoch 00010: val_accuracy did not improve from 0.89116
# 74/74 [==============================] - 9s 116ms/step - loss: 0.0824 - accuracy: 0.9728 - val_loss: 1.1734 - val_accuracy: 0.7857 - lr: 0.0010
# Epoch 11/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9747
# Epoch 00011: val_accuracy did not improve from 0.89116
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 74/74 [==============================] - 9s 116ms/step - loss: 0.0673 - accuracy: 0.9749 - val_loss: 0.4910 - val_accuracy: 0.8861 - lr: 0.0010
# Epoch 12/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0450 - accuracy: 0.9867
# Epoch 00012: val_accuracy did not improve from 0.89116
# 74/74 [==============================] - 8s 109ms/step - loss: 0.0447 - accuracy: 0.9868 - val_loss: 0.4960 - val_accuracy: 0.8912 - lr: 3.0000e-04
# Epoch 13/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9897
# Epoch 00013: val_accuracy improved from 0.89116 to 0.89286, saving model to effnet.h5
# 74/74 [==============================] - 8s 111ms/step - loss: 0.0320 - accuracy: 0.9898 - val_loss: 0.5149 - val_accuracy: 0.8929 - lr: 3.0000e-04
# Epoch 14/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0236 - accuracy: 0.9936
# Epoch 00014: val_accuracy did not improve from 0.89286
# 74/74 [==============================] - 8s 109ms/step - loss: 0.0237 - accuracy: 0.9936 - val_loss: 0.4864 - val_accuracy: 0.8895 - lr: 3.0000e-04
# Epoch 15/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 0.9940
# Epoch 00015: val_accuracy improved from 0.89286 to 0.89626, saving model to effnet.h5
# 74/74 [==============================] - 9s 118ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.5468 - val_accuracy: 0.8963 - lr: 3.0000e-04
# Epoch 16/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9932
# Epoch 00016: val_accuracy improved from 0.89626 to 0.91667, saving model to effnet.h5
# 74/74 [==============================] - 9s 118ms/step - loss: 0.0227 - accuracy: 0.9932 - val_loss: 0.4717 - val_accuracy: 0.9167 - lr: 3.0000e-04
# Epoch 17/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9923
# Epoch 00017: val_accuracy did not improve from 0.91667
# 74/74 [==============================] - 8s 110ms/step - loss: 0.0206 - accuracy: 0.9923 - val_loss: 0.4600 - val_accuracy: 0.9133 - lr: 3.0000e-04
# Epoch 18/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9983
# Epoch 00018: val_accuracy did not improve from 0.91667
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 74/74 [==============================] - 8s 110ms/step - loss: 0.0101 - accuracy: 0.9983 - val_loss: 0.7338 - val_accuracy: 0.8639 - lr: 3.0000e-04
# Epoch 19/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9970
# Epoch 00019: val_accuracy did not improve from 0.91667
# 74/74 [==============================] - 9s 117ms/step - loss: 0.0125 - accuracy: 0.9970 - val_loss: 0.4934 - val_accuracy: 0.9065 - lr: 9.0000e-05
# Epoch 20/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9974
# Epoch 00020: val_accuracy did not improve from 0.91667
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 74/74 [==============================] - 9s 116ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.5015 - val_accuracy: 0.9082 - lr: 9.0000e-05
# Epoch 21/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9957
# Epoch 00021: val_accuracy did not improve from 0.91667
# 74/74 [==============================] - 9s 117ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.5715 - val_accuracy: 0.8912 - lr: 2.7000e-05
# Epoch 22/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9970
# Epoch 00022: val_accuracy did not improve from 0.91667
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 74/74 [==============================] - 9s 117ms/step - loss: 0.0135 - accuracy: 0.9970 - val_loss: 0.5795 - val_accuracy: 0.8878 - lr: 2.7000e-05
# Epoch 23/25
# 74/74 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9970
# Epoch 00023: val_accuracy did not improve from 0.91667
# 74/74 [==============================] - 8s 110ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.5085 - val_accuracy: 0.9048 - lr: 8.1000e-06
# Epoch 24/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 0.9961
# Epoch 00024: val_accuracy did not improve from 0.91667
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 74/74 [==============================] - 9s 116ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.5190 - val_accuracy: 0.9031 - lr: 8.1000e-06
# Epoch 25/25
# 73/74 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9979
# Epoch 00025: val_accuracy did not improve from 0.91667
# 74/74 [==============================] - 9s 117ms/step - loss: 0.0101 - accuracy: 0.9979 - val_loss: 0.5103 - val_accuracy: 0.9048 - lr: 2.4300e-06

# %%
#Graphing our training and validation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(15, 8))

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy', fontsize=20)
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend()
plt.figure()


plt.figure(figsize=(15, 8))

epochs = range(len(loss))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss', fontsize=20)
plt.ylabel('loss') 
plt.xlabel('epoch')
plt.legend()
plt.figure()

# %%
pred = model_cnn.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        93
#            1       0.94      0.86      0.90        51
#            2       0.87      0.85      0.86        96
#            3       0.96      0.99      0.97        87
#
#     accuracy                           0.90       327
#    macro avg       0.90      0.90      0.90       327
# weighted avg       0.90      0.90      0.90       327

# %%
#Prediction of test set
from sklearn.metrics import confusion_matrix 
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 10))

conf_matrix = confusion_matrix(y_test_new,pred)
sns.heatmap(conf_matrix,annot=True,fmt='g');
plt.xlabel('predicted value')
plt.ylabel('true value');

plt.figure()

# %%
# Training Accuracy
train_pred = model_cnn.predict(X_train)
train_pred = np.argmax(train_pred, axis=1)
y_train_new = np.argmax(y_train, axis=1)

count_train = 0
for i in range(0, len(train_pred)):
  if train_pred[i] == y_train_new[i]:
    count_train += 1

x1 = count_train/len(train_pred)

# Validation Accuracy
test_pred = model_cnn.predict(X_test)
test_pred = np.argmax(test_pred, axis=1)
y_test_new = np.argmax(y_test, axis=1)

count_test = 0
for i in range(0, len(test_pred)):
  if test_pred[i] == y_test_new[i]:
    count_test += 1

x2 = count_test/len(test_pred)

print('Training Accuracy  : %1.2f%%'%(x1*100))
print('Validation Accuracy: %1.2f%%'%(x2*100))
# Out:
# Training Accuracy  : 98.03%
# Validation Accuracy: 89.91%
